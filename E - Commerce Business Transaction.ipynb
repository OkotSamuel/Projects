# %%
import pandas as pd

# %%
data= pd.read_csv(r"C:\Users\PC ZED\Desktop\DATA SETS\Sales Transaction v.4a.csv")

# %%
data
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
# Creating new column named 'Total_Amount'

# %%
data.insert(8,'Total_Amount',data['Price']* data['Quantity'])

# %%
data.dtypes
# Out:
# TransactionNo     object
# Date              object
# ProductNo         object
# ProductName       object
# Price            float64
# Quantity           int64
# CustomerNo       float64
# Country           object
# Total_Amount     float64
# dtype: object

# %%
# Looking for null values.

# %%
data.isnull().sum()
# Out:
# TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# Total_Amount      0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.head(2)
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
#
#    Price  Quantity  CustomerNo         Country  Total_Amount
# 0  21.47        12     17490.0  United Kingdom        257.64
# 1  10.65        36     13069.0  United Kingdom        383.40

# %%
data[data['CustomerNo'].isnull()]
# Out:
#        TransactionNo        Date ProductNo  \
# 6511         C581406   12/8/2019    46000M
# 6512         C581406   12/8/2019    46000S
# 90098        C575153   11/8/2019     22947
# 102671       C574288   11/3/2019     22178
# 117263       C573180  10/28/2019     23048
# 163160       C569495   10/4/2019     21843
# 190598       C567518   9/20/2019     22846
# 192284       C567518   9/20/2019     21871
# 242406       C563015   8/11/2019    46000M
# 242407       C563015   8/11/2019    46000S
# 246334       C562617    8/8/2019     23243
# 254250       C561966    8/1/2019     22371
# 254254       C562030    8/1/2019    84595E
# 260633       C561239   7/26/2019     22427
# 260634       C561239   7/26/2019     22426
# 260635       C561239   7/26/2019     84755
# 276396       C559949   7/14/2019     22699
# 285494       C559296    7/7/2019     23001
# 285495       C559296    7/7/2019     22616
# 285496       C559296    7/7/2019     23298
# 297259       C558364   6/28/2019     22960
# ...

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# TransactionNo    0
# Date             0
# ProductNo        0
# ProductName      0
# Price            0
# Quantity         0
# CustomerNo       0
# Country          0
# Total_Amount     0
# dtype: int64

# %%
data.head()
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country  Total_Amount
# 0  21.47        12     17490.0  United Kingdom        257.64
# 1  10.65        36     13069.0  United Kingdom        383.40
# 2  11.53        12     13069.0  United Kingdom        138.36
# 3  10.65        12     13069.0  United Kingdom        127.80
# 4  11.94         6     13069.0  United Kingdom         71.64

# %%
# Find the number of cancelled transactions shown by negative quantities.

# %%
data[data['Quantity'] < 0]
# Out:
#        TransactionNo       Date ProductNo                       ProductName  \
# 1616         C581484  12/9/2019     23843         Paper Craft Little Birdie
# 1617         C581490  12/9/2019     22178   Victorian Glass Hanging T-Light
# 1618         C581490  12/9/2019     23144   Zinc T-Light Holder Stars Small
# 1619         C581568  12/9/2019     21258        Victorian Sewing Box Large
# 1620         C581569  12/9/2019     84978  Hanging Heart Jar T-Light Holder
# ...              ...        ...       ...                               ...
# 536345       C536548  12/1/2018     22168      Organiser Wood Antique White
# 536346       C536548  12/1/2018     21218            Red Spotty Biscuit Tin
# 536347       C536548  12/1/2018     20957      Porcelain Hanging Bell Small
# 536348       C536548  12/1/2018     22580      Advent Calendar Gingham Sack
# 536349       C536548  12/1/2018     22767        Triple Photo Frame Cornice
#
# ...

# %%
# Replacing the negatives in Quantity with zero.

# %%
data['Quantity'][data['Quantity'] < 0] = 0
# Out:
# C:\Users\PC ZED\AppData\Local\Temp\ipykernel_4844\2644753015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Quantity'][data['Quantity'] < 0] = 0

# %%
data
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
# Updating the total amounts for the new Quantities.

# %%
data.drop(columns = 'Total_Amount', inplace = True)

# %%
data.head(2)
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom

# %%
data.insert(8,'Total_Amount',data['Price'] * data['Quantity'])

# %%
data
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
# What are the most frequently purchased products?

# %%
data['ProductName'].value_counts()
# Out:
# Cream Hanging Heart T-Light Holder    2378
# Regency Cakestand 3 Tier              2200
# Jumbo Bag Red Retrospot               2159
# Party Bunting                         1727
# Lunch Bag Red Retrospot               1639
#                                       ...
# Blue Drop Earrings W Bead Cluster        1
# Pink Chrysanthemums Art Flower           1
# Necklace+Bracelet Set Pink Daisy         1
# Scallop Shell Soap Dish                  1
# Porcelain Hanging Bell Small             1
# Name: ProductName, Length: 3767, dtype: int64

# %%
# How many products does the customer purchase in each transaction?

# %%
data.head(2)
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
#
#    Price  Quantity  CustomerNo         Country  Total_Amount
# 0  21.47        12     17490.0  United Kingdom        257.64
# 1  10.65        36     13069.0  United Kingdom        383.40

# %%
data.groupby('TransactionNo')['CustomerNo','Quantity'].sum()
# Out:
# C:\Users\PC ZED\AppData\Local\Temp\ipykernel_4844\1486951391.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('TransactionNo')['CustomerNo','Quantity'].sum()
#                CustomerNo  Quantity
# TransactionNo
# 536365           124950.0        40
# 536366            35700.0        12
# 536367           156564.0        83
# 536368            52188.0        15
# 536369            13047.0         3
# ...                   ...       ...
# C581470           17924.0         0
# C581484           16446.0         0
# C581490           28794.0         0
# C581568           15311.0         0
# C581569           34630.0         0
#
# [23168 rows x 2 columns]

# %%
# What are the most profitable segment customers?

# %%
data.head()
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country  Total_Amount
# 0  21.47        12     17490.0  United Kingdom        257.64
# 1  10.65        36     13069.0  United Kingdom        383.40
# 2  11.53        12     13069.0  United Kingdom        138.36
# 3  10.65        12     13069.0  United Kingdom        127.80
# 4  11.94         6     13069.0  United Kingdom         71.64

# %%
data.groupby('Country')['Total_Amount'].sum().sort_values(ascending = False)
# Out:
# Country
# United Kingdom          52524576.47
# Netherlands              2151553.59
# EIRE                     1713410.95
# Germany                  1371543.27
# France                   1330652.89
# Australia                 995607.91
# Sweden                    401879.89
# Switzerland               361969.25
# Japan                     293155.44
# Spain                     281012.27
# Belgium                   272131.88
# Norway                    188612.52
# Portugal                  176110.40
# Finland                   120972.15
# Denmark                   101083.99
# Channel Islands            95932.24
# Italy                      78536.24
# Austria                    69147.26
# Singapore                  63480.95
# Cyprus                     62346.75
# Israel                     54943.36
# Iceland                    38321.90
# USA                        32868.65
# Unspecified                32699.05
# Canada                     30490.91
# Hong Kong                  27835.50
# ...

# %%
# How was the sales trend over the months?

# %%
data['Month'] = pd.to_datetime(data['Date']).dt.month_name()

# %%
data
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
# Removing the cancelled transactions.

# %%
data.head(2)
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
#
#    Price  Quantity  CustomerNo         Country  Total_Amount     Month
# 0  21.47        12     17490.0  United Kingdom        257.64  December
# 1  10.65        36     13069.0  United Kingdom        383.40  December

# %%
data[data['Quantity']==0]
# Out:
#        TransactionNo       Date ProductNo                       ProductName  \
# 1616         C581484  12/9/2019     23843         Paper Craft Little Birdie
# 1617         C581490  12/9/2019     22178   Victorian Glass Hanging T-Light
# 1618         C581490  12/9/2019     23144   Zinc T-Light Holder Stars Small
# 1619         C581568  12/9/2019     21258        Victorian Sewing Box Large
# 1620         C581569  12/9/2019     84978  Hanging Heart Jar T-Light Holder
# ...              ...        ...       ...                               ...
# 536345       C536548  12/1/2018     22168      Organiser Wood Antique White
# 536346       C536548  12/1/2018     21218            Red Spotty Biscuit Tin
# 536347       C536548  12/1/2018     20957      Porcelain Hanging Bell Small
# 536348       C536548  12/1/2018     22580      Advent Calendar Gingham Sack
# 536349       C536548  12/1/2018     22767        Triple Photo Frame Cornice
#
# ...

# %%
result = data[data['Quantity']==0].index

# %%
data = data.drop(index =result)

# %%
data
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536320        536585  12/1/2018     37449
# 536321        536590  12/1/2018     22776
# 536322        536590  12/1/2018     22622
# 536323        536591  12/1/2018     37449
# 536324        536597  12/1/2018     22220
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
data['Month_Num'] = pd.to_datetime(data['Date']).dt.month

# %%
data
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536320        536585  12/1/2018     37449
# 536321        536590  12/1/2018     22776
# 536322        536590  12/1/2018     22622
# 536323        536591  12/1/2018     37449
# 536324        536597  12/1/2018     22220
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
print(type(data.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df = data.sort_values(by='Month_Num',ascending= True)

# %%
df.head(2)
# Out:
#        TransactionNo       Date ProductNo                         ProductName  \
# 470051        541809 2019-01-21    85123A  Cream Hanging Heart T-Light Holder
# 471157        541648 2019-01-20     22498              Wooden Regatta Bunting
#
#         Price  Quantity  CustomerNo         Country  Total_Amount    Month  \
# 470051  17.05         1     16809.0  United Kingdom         17.05  January
# 471157  16.35         2     17811.0  United Kingdom         32.70  January
#
#         Month_Num
# 470051          1
# 471157          1

# %%
df['Total_Amount']= df['Total_Amount'].astype(int)

# %%
df.head(2)
# Out:
#        TransactionNo       Date ProductNo                         ProductName  \
# 470051        541809 2019-01-21    85123A  Cream Hanging Heart T-Light Holder
# 471157        541648 2019-01-20     22498              Wooden Regatta Bunting
#
#         Price  Quantity  CustomerNo         Country  Total_Amount    Month  \
# 470051  17.05         1     16809.0  United Kingdom            17  January
# 471157  16.35         2     17811.0  United Kingdom            32  January
#
#         Month_Num
# 470051          1
# 471157          1

# %%
df.groupby('Month')['Total_Amount'].sum()
# Out:
# Month
# April        3575582
# August       4741681
# December     6899607
# February     3322061
# January      4543213
# July         4575094
# June         4477068
# March        4381329
# May          4561460
# November     7822576
# October      7209045
# September    6604482
# Name: Total_Amount, dtype: int32

# %%
dates_in_order = pd.date_range(start='2022-01-01', end='2022-12-01', freq='MS')

# %%
months_in_order = dates_in_order.map(lambda x: x.month_name()).to_list()

# %%
df.Month = pd.Categorical(
    df.Month,
    categories=months_in_order,
    ordered=True
)

# %%
df.sort_values('Month')
# Out:
#        TransactionNo       Date ProductNo                         ProductName  \
# 470051        541809 2019-01-21    85123A  Cream Hanging Heart T-Light Holder
# 494213        540028 2019-01-04    84968D       Set Of 16 Vintage Red Cutlery
# 494214        540043 2019-01-04     85066         Cream Sweetheart Mini Chest
# 494247        540098 2019-01-04     21623        Vintage Union Jack Memoboard
# 494246        540096 2019-01-04     22782        Set 3 Wicker Storage Baskets
# ...              ...        ...       ...                                 ...
# 502597        539099 2018-12-16     22897             Oven Mitt Apples Design
# 510975        538510 2018-12-12     21136        Painted Metal Pears Assorted
# 510991        538511 2018-12-12     21041     Red Retrospot Oven Glove Double
# 511023        538513 2018-12-12     22127       Party Cones Carnival Assorted
# 536324        536597 2018-12-01     22220    Cake Stand Lovebird 2 Tier White
#
# ...

# %%
pivot = pd.pivot_table(df,
                     index = ["Month"],
                     values = ["Total_Amount"],
                     aggfunc = "sum")

# %%
pivot
# Out:
#            Total_Amount
# Month
# January         4543213
# February        3322061
# March           4381329
# April           3575582
# May             4561460
# June            4477068
# July            4575094
# August          4741681
# September       6604482
# October         7209045
# November        7822576
# December        6899607

# %%
pivot.plot(figsize = (10,5),marker = 'o', ylabel = 'Total_Amount')
plt.title('Total_Amount by Month')
plt.show()

# %% [markdown]
# The sales are highest in the third quarter of the year, with the highest sales recorded in November.
# The high sales in the third quarter are attributed to the holiday and festive seasons.
# The first and second quarter have low sales and i would suggest offering incentives like discounts and rewards to customers and creating marketing strategies to boost sales.
