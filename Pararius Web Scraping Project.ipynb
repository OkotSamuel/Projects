# %% [markdown]
#  In the following project, i am going to scrape data from the Pararius website for apartments in the Netherlands.

# %%
import requests
import csv
from bs4 import BeautifulSoup

# %%
url = "https://www.pararius.com/apartments/amsterdam"
page = requests.get(url)

# %%
print(page)
# Out:
# <Response [200]>

# %%
data = soup.find_all('section', class_="listing-search-item")

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
with open('Housing_data.csv','w',encoding = 'UTF8',newline = '') as f:
    writer = csv.writer(f)
    header = ['Title','Price','Size','Number_of_rooms']
    writer.writerow(header)
    for i in data:
        title = i.find('a',class_="listing-search-item__link--title").text.replace('\n','')
        price = i.find('div',class_="listing-search-item__price").text.replace('\n','')
        size = i.find('li',class_="illustrated-features__item--surface-area").text.replace('\n','')
        rooms = i.find('li',class_="illustrated-features__item--number-of-rooms").text.replace('\n','')
        info = [title,price,size,rooms]
        writer.writerow(info)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\PC ZED\Desktop\Working_Files\Housing_data.csv")

# %%
df
# Out:
#                                                 Title  \
# 0                           Apartment Reguliersgra...
# 1                           Apartment Keizersgrach...
# 2                           Apartment Baetostraat ...
# 3                           Apartment Keizersgrach...
# 4                           Apartment De Lairesses...
# 5                           Apartment Maria Austri...
# 6                           Apartment Van Tuyll va...
# 7                           House Emmy Andriessest...
# 8                           Apartment Holendrechts...
# 9                           Apartment Tweede Ooste...
# 10                          Apartment Ruys de Beer...
# 11                          Apartment Frieslandstr...
# 12                          Apartment Weesperzijde...
# 13                          Apartment Binnenkant  ...
# 14                          Apartment Prinsengrach...
# 15                          Apartment Lauriergrach...
# ...
